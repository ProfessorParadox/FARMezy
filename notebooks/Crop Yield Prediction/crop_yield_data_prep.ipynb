# %%
import numpy as np 
import pandas as pd

# %%
df_yield = pd.read_csv('yields.csv')
df_yield.shape
# Out:
# (246091, 7)

# %%
df_yield.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop  Area(Hectare)  Production(Tonnes)
# 0             Arecanut         1254.0              2000.0
# 1  Other Kharif pulses            2.0                 1.0
# 2                 Rice          102.0               321.0
# 3               Banana          176.0               641.0
# 4            Cashewnut          720.0               165.0

# %%
df_yield.tail()
# Out:
#          State_Name District_Name  Crop_Year       Season       Crop  \
# 246086  West Bengal       PURULIA       2014  Summer            Rice
# 246087  West Bengal       PURULIA       2014  Summer         Sesamum
# 246088  West Bengal       PURULIA       2014  Whole Year   Sugarcane
# 246089  West Bengal       PURULIA       2014  Winter            Rice
# 246090  West Bengal       PURULIA       2014  Winter         Sesamum
#
#         Area(Hectare)  Production(Tonnes)
# 246086          306.0               801.0
# 246087          627.0               463.0
# 246088          324.0             16250.0
# 246089       279151.0            597899.0
# 246090          175.0                88.0

# %%
df_yield['Yield'] = df_yield['Production(Tonnes)']/df_yield['Area(Hectare)']

# %%
df_yield.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop  Area(Hectare)  Production(Tonnes)     Yield
# 0             Arecanut         1254.0              2000.0  1.594896
# 1  Other Kharif pulses            2.0                 1.0  0.500000
# 2                 Rice          102.0               321.0  3.147059
# 3               Banana          176.0               641.0  3.642045
# 4            Cashewnut          720.0               165.0  0.229167

# %%
df_yield.drop(columns=['Area(Hectare)', 'Production(Tonnes)'], inplace = True)
df_yield.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop     Yield
# 0             Arecanut  1.594896
# 1  Other Kharif pulses  0.500000
# 2                 Rice  3.147059
# 3               Banana  3.642045
# 4            Cashewnut  0.229167

# %%
df_yield = df_yield.rename(index=str, columns={"Yield": "tonnes/hectare_yield"})

# %%
df_yield.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop  tonnes/hectare_yield
# 0             Arecanut              1.594896
# 1  Other Kharif pulses              0.500000
# 2                 Rice              3.147059
# 3               Banana              3.642045
# 4            Cashewnut              0.229167

# %%
df_yield.describe()
# Out:
#            Crop_Year  tonnes/hectare_yield
# count  246091.000000         242361.000000
# mean     2005.643018             41.649059
# std         4.952164            817.572839
# min      1997.000000              0.000000
# 25%      2002.000000              0.513514
# 50%      2006.000000              1.000000
# 75%      2010.000000              2.355450
# max      2015.000000          88000.000000

# %%
df_yield['State_Name'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df_rain = pd.read_csv('StateWiseRainfall.csv')
df_rain.shape
# Out:
# (4188, 19)

# %%
df_rain.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  Andaman & Nicobar Islands  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  Andaman & Nicobar Islands  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  Andaman & Nicobar Islands  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  Andaman & Nicobar Islands  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM    JJAS  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2  136.3  560.3  1696.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7  159.8  458.3  2185.9
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4  156.7  236.1  1874.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6   24.1  506.9  1977.6
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7    1.3  309.7  1624.9
#
#      OND
# 0  980.3
# 1  716.7
# 2  690.6
# 3  571.0
# 4  630.8

# %%
df_rain_states = df_rain['State_Name'].unique()

# %%
df_yield_states = df_yield['State_Name'].unique()

# %%
df_yield['Season'].unique()
# Out:
# array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
df_rain = df_rain[df_rain['YEAR']>=1997]

# %%
df_rain.shape
# Out:
# (756, 19)

# %%
df_rain.head()
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1997   9.5   0.0    0.2   15.6  281.1  199.5
# 1  Andaman & Nicobar Islands  1998   0.9   0.0    0.0    0.0  348.9  600.0
# 2  Andaman & Nicobar Islands  1999  46.8  44.6   14.2  270.6  257.4  295.0
# 3  Andaman & Nicobar Islands  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 4  Andaman & Nicobar Islands  2001  89.0  15.7  143.3   30.1  705.3  370.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM    JJAS  \
# 0  918.5  430.6  440.2  128.7  292.8   38.4  2755.1    9.5  296.9  1988.8
# 1  364.5  258.9  337.8  618.6  227.8   89.0  2846.4    0.9  348.9  1561.2
# 2  408.5  329.2  325.3  437.5  124.9  145.7  2699.7   91.4  542.2  1358.0
# 3  176.3  460.8  250.1  321.2  158.3  115.2  2763.2  112.0  812.2  1244.2
# 4  341.3  469.0  334.4  267.6  222.6   91.8  3080.9  104.7  878.7  1515.4
#
#      OND
# 0  459.9
# 1  935.4
# 2  708.1
# 3  594.7
# 4  582.0

# %%
df_rain.drop(columns = ['JF','MAM','JJAS','OND'], inplace = True)
# Out:
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_rain.head()
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1997   9.5   0.0    0.2   15.6  281.1  199.5
# 1  Andaman & Nicobar Islands  1998   0.9   0.0    0.0    0.0  348.9  600.0
# 2  Andaman & Nicobar Islands  1999  46.8  44.6   14.2  270.6  257.4  295.0
# 3  Andaman & Nicobar Islands  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 4  Andaman & Nicobar Islands  2001  89.0  15.7  143.3   30.1  705.3  370.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL
# 0  918.5  430.6  440.2  128.7  292.8   38.4  2755.1
# 1  364.5  258.9  337.8  618.6  227.8   89.0  2846.4
# 2  408.5  329.2  325.3  437.5  124.9  145.7  2699.7
# 3  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 4  341.3  469.0  334.4  267.6  222.6   91.8  3080.9

# %%
df_rain = df_rain.rename(index=str, columns={"ANNUAL": "Whole Year"})

# %%
df_rain.head()
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1997   9.5   0.0    0.2   15.6  281.1  199.5
# 1  Andaman & Nicobar Islands  1998   0.9   0.0    0.0    0.0  348.9  600.0
# 2  Andaman & Nicobar Islands  1999  46.8  44.6   14.2  270.6  257.4  295.0
# 3  Andaman & Nicobar Islands  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 4  Andaman & Nicobar Islands  2001  89.0  15.7  143.3   30.1  705.3  370.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  Whole Year
# 0  918.5  430.6  440.2  128.7  292.8   38.4      2755.1
# 1  364.5  258.9  337.8  618.6  227.8   89.0      2846.4
# 2  408.5  329.2  325.3  437.5  124.9  145.7      2699.7
# 3  176.3  460.8  250.1  321.2  158.3  115.2      2763.2
# 4  341.3  469.0  334.4  267.6  222.6   91.8      3080.9

# %%
df_rain['Kharif'] = df_rain['JUN'] + df_rain['JUL'] + df_rain['AUG'] + df_rain['SEP'] + df_rain['OCT']
df_rain['Autumn'] = df_rain['SEP'] + df_rain['OCT']
df_rain['Rabi'] = df_rain['NOV'] + df_rain['DEC'] + df_rain['JAN'] + df_rain['FEB'] + df_rain['MAR'] + df_rain['APR']
df_rain['Summer'] = df_rain['APR'] + df_rain['MAY'] + df_rain['JUN']
df_rain['Winter'] = df_rain['NOV'] + df_rain['DEC'] + df_rain['JAN'] + df_rain['FEB']

# %%
df_rain.head()
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1997   9.5   0.0    0.2   15.6  281.1  199.5
# 1  Andaman & Nicobar Islands  1998   0.9   0.0    0.0    0.0  348.9  600.0
# 2  Andaman & Nicobar Islands  1999  46.8  44.6   14.2  270.6  257.4  295.0
# 3  Andaman & Nicobar Islands  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 4  Andaman & Nicobar Islands  2001  89.0  15.7  143.3   30.1  705.3  370.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  Whole Year  Kharif  Autumn  \
# 0  918.5  430.6  440.2  128.7  292.8   38.4      2755.1  2117.5   568.9
# 1  364.5  258.9  337.8  618.6  227.8   89.0      2846.4  2179.8   956.4
# 2  408.5  329.2  325.3  437.5  124.9  145.7      2699.7  1795.5   762.8
# 3  176.3  460.8  250.1  321.2  158.3  115.2      2763.2  1565.4   571.3
# 4  341.3  469.0  334.4  267.6  222.6   91.8      3080.9  1783.0   602.0
#
#     Rabi  Summer  Winter
# 0  356.5   496.2   340.7
# 1  317.7   948.9   317.7
# ...

# %%
df_rain.drop(columns=['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'], inplace = True)

# %%
df_rain.head()
# Out:
#                  SUBDIVISION  YEAR  Whole Year  Kharif  Autumn   Rabi  Summer  \
# 0  Andaman & Nicobar Islands  1997      2755.1  2117.5   568.9  356.5   496.2
# 1  Andaman & Nicobar Islands  1998      2846.4  2179.8   956.4  317.7   948.9
# 2  Andaman & Nicobar Islands  1999      2699.7  1795.5   762.8  646.8   823.0
# 3  Andaman & Nicobar Islands  2000      2763.2  1565.4   571.3  774.9   997.9
# 4  Andaman & Nicobar Islands  2001      3080.9  1783.0   602.0  592.5  1106.1
#
#    Winter
# 0   340.7
# 1   317.7
# 2   362.0
# 3   385.5
# 4   419.1

# %%
df_rain.shape
# Out:
# (756, 8)

# %%
df_yield.drop(columns=['District_Name'], inplace = True)

# %%
df_yield.head()
# Out:
#                     State_Name  Crop_Year       Season                 Crop  \
# 0  Andaman and Nicobar Islands       2000  Kharif                  Arecanut
# 1  Andaman and Nicobar Islands       2000  Kharif       Other Kharif pulses
# 2  Andaman and Nicobar Islands       2000  Kharif                      Rice
# 3  Andaman and Nicobar Islands       2000  Whole Year                Banana
# 4  Andaman and Nicobar Islands       2000  Whole Year             Cashewnut
#
#    tonnes/hectare_yield
# 0              1.594896
# 1              0.500000
# 2              3.147059
# 3              3.642045
# 4              0.229167

# %%
df_rain = df_rain.rename(index=str, columns={"SUBDIVISION": "State_Name"})

# %%
df_rain = df_rain.rename(index=str, columns={"YEAR": "Crop_Year"})

# %%
df_rain.head()
# Out:
#                   State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  \
# 0  Andaman & Nicobar Islands       1997      2755.1  2117.5   568.9  356.5
# 1  Andaman & Nicobar Islands       1998      2846.4  2179.8   956.4  317.7
# 2  Andaman & Nicobar Islands       1999      2699.7  1795.5   762.8  646.8
# 3  Andaman & Nicobar Islands       2000      2763.2  1565.4   571.3  774.9
# 4  Andaman & Nicobar Islands       2001      3080.9  1783.0   602.0  592.5
#
#    Summer  Winter
# 0   496.2   340.7
# 1   948.9   317.7
# 2   823.0   362.0
# 3   997.9   385.5
# 4  1106.1   419.1

# %%
df_rain.State_Name[df_rain['State_Name']=='Andaman & Nicobar Islands'] = 'Andaman and Nicobar Islands'
df_rain.head()
# Out:
# <ipython-input-55-b8babb30c35d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain.State_Name[df_rain['State_Name']=='Andaman & Nicobar Islands'] = 'Andaman and Nicobar Islands'
#                     State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  \
# 0  Andaman and Nicobar Islands       1997      2755.1  2117.5   568.9  356.5
# 1  Andaman and Nicobar Islands       1998      2846.4  2179.8   956.4  317.7
# 2  Andaman and Nicobar Islands       1999      2699.7  1795.5   762.8  646.8
# 3  Andaman and Nicobar Islands       2000      2763.2  1565.4   571.3  774.9
# 4  Andaman and Nicobar Islands       2001      3080.9  1783.0   602.0  592.5
#
#    Summer  Winter
# 0   496.2   340.7
# 1   948.9   317.7
# 2   823.0   362.0
# 3   997.9   385.5
# 4  1106.1   419.1

# %%
df_rain.to_csv('rainfall_mm__per_season_per_district_kp.csv', index = False)

# %%
df_yield.to_csv('yields_partially_processed_kp.csv', index = False)

# %%
df_rain_states = df_rain['State_Name'].unique()
df_yield_states = df_yield['State_Name'].unique()
print(df_rain_states)
print(df_yield_states)
# Out:
# ['Andaman and Nicobar Islands' 'Arunachal Pradesh' 'Sikkim' 'Odisha'
#  'Jharkhand' 'Bihar' 'Uttarakhand' 'Punjab' 'Himachal Pradesh'
#  'Jammu and Kashmir' 'Gujarat' 'Goa' 'Maharashtra' 'Chhattisgarh'
#  'Andhra Pradesh' 'Telangana' 'Tamil Nadu' 'Kerala' 'Meghalaya' 'Assam'
#  'Dadra and Nagar Haveli' 'Tripura' 'Manipur' 'Mizoram' 'Nagaland'
#  'Haryana' 'Chandigarh' 'Uttar Pradesh' 'Rajasthan' 'Madhya Pradesh'
#  'Karnataka' 'West Bengal']
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh' 'Dadra and Nagar Haveli'
#  'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir'
#  'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Punjab' 'Rajasthan' 'Sikkim'
#  'Tamil Nadu' 'Telangana' 'Tripura' 'Uttar Pradesh' 'Uttarakhand'
#  'West Bengal']

# %%
for state in df_rain_states:
    if state in df_yield_states:
        print(state)
# Out:
# Andaman and Nicobar Islands
# Arunachal Pradesh
# Sikkim
# Odisha
# Jharkhand
# Bihar
# Uttarakhand
# Punjab
# Himachal Pradesh
# Jammu and Kashmir
# Gujarat
# Goa
# Maharashtra
# Chhattisgarh
# Andhra Pradesh
# Telangana
# Tamil Nadu
# Kerala
# Meghalaya
# Assam
# Dadra and Nagar Haveli
# Tripura
# Manipur
# Mizoram
# Nagaland
# Haryana
# Chandigarh
# Uttar Pradesh
# Rajasthan
# Madhya Pradesh
# Karnataka
# West Bengal

# %%
for state in df_rain_states:
    if state not in df_yield_states:
        print(state)

# %%
for state in df_yield_states:
    if state not in df_rain_states:
        print(state)

# %%
import copy
df_rain_temp = df_rain[df_rain['State_Name']=='Assam & Meghalaya']

# %%
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_deep['State_Name'] = 'Meghalaya'
df_rain = df_rain.append(df_rain_deep)

# %%
df_rain_deep['State_Name'] = 'Assam'
df_rain = df_rain.append(df_rain_deep)

# %%
#Checkpoint
df_rain.to_csv('rainfall_mm__per_season_per_district_3.csv', index = False)

# %%
df_rain.shape
# Out:
# (798, 8)

# %%
df_rain.tail(50)
# Out:
#       State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  Winter
# 748  Lakshadweep       2010      1725.2  1307.6   316.9  338.6   433.5   301.8
# 749  Lakshadweep       2011      1533.7  1130.4   372.6  296.1   346.7   207.1
# 750  Lakshadweep       2012      1405.5  1265.4   325.7  118.9   425.0    40.5
# 751  Lakshadweep       2013      1426.3  1129.8   252.8  208.2   519.8   165.4
# 752  Lakshadweep       2014      1395.0  1127.7   301.4  209.9   316.4   190.6
# 753  Lakshadweep       2015      1642.9  1026.3   325.8  483.5   516.8   392.7
# 754  Lakshadweep       2016      1065.7   804.1   134.2  184.2   401.1   178.4
# 755  Lakshadweep       2017      1738.9  1245.4   353.1  347.8   669.4   245.8
# 42     Meghalaya       1997      2372.2  1799.8   403.2  330.6   943.6   106.9
# 43     Meghalaya       1998      2803.1  2137.4   402.3  415.1  1017.5    92.6
# 44     Meghalaya       1999      2594.2  1918.7   405.5  208.6  1046.4    19.3
# ...

# %%
df_rain = df_rain[df_rain['State_Name']!='Assam & Meghalaya']

# %%
df_rain['Kharif'][df_rain['State_Name']=='Assam'] = df_rain['Kharif'][df_rain['State_Name']=='Assam'].apply(lambda x:x/2)
df_rain['Whole Year'][df_rain['State_Name']=='Assam'] = df_rain['Whole Year'][df_rain['State_Name']=='Assam'].apply(lambda x:x/2)
df_rain['Rabi'][df_rain['State_Name']=='Assam'] = df_rain['Rabi'][df_rain['State_Name']=='Assam'].apply(lambda x:x/2)
df_rain['Winter'][df_rain['State_Name']=='Assam'] = df_rain['Winter'][df_rain['State_Name']=='Assam'].apply(lambda x:x/2)
df_rain['Autumn'][df_rain['State_Name']=='Assam'] = df_rain['Autumn'][df_rain['State_Name']=='Assam'].apply(lambda x:x/2)
df_rain['Summer'][df_rain['State_Name']=='Assam'] = df_rain['Summer'][df_rain['State_Name']=='Assam'].apply(lambda x:x/2)
# Out:
# <ipython-input-142-abbe01d4204e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Kharif'][df_rain['State_Name']=='Assam'] = df_rain['Kharif'][df_rain['State_Name']=='Assam'].apply(lambda x:x/2)
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df_rain['Kharif'][df_rain['State_Name']=='Meghalaya'] = df_rain['Kharif'][df_rain['State_Name']=='Meghalaya'].apply(lambda x:x/2)
df_rain['Whole Year'][df_rain['State_Name']=='Meghalaya'] = df_rain['Whole Year'][df_rain['State_Name']=='Meghalaya'].apply(lambda x:x/2)
df_rain['Rabi'][df_rain['State_Name']=='Meghalaya'] = df_rain['Rabi'][df_rain['State_Name']=='Meghalaya'].apply(lambda x:x/2)
df_rain['Winter'][df_rain['State_Name']=='Meghalaya'] = df_rain['Winter'][df_rain['State_Name']=='Meghalaya'].apply(lambda x:x/2)
df_rain['Autumn'][df_rain['State_Name']=='Meghalaya'] = df_rain['Autumn'][df_rain['State_Name']=='Meghalaya'].apply(lambda x:x/2)
df_rain['Summer'][df_rain['State_Name']=='Meghalaya'] = df_rain['Summer'][df_rain['State_Name']=='Meghalaya'].apply(lambda x:x/2)
# Out:
# <ipython-input-144-48801be04cf2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Kharif'][df_rain['State_Name']=='Meghalaya'] = df_rain['Kharif'][df_rain['State_Name']=='Meghalaya'].apply(lambda x:x/2)
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-144-48801be04cf2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_rain.tail(60)
# Out:
#                  State_Name  Crop_Year  Whole Year   Kharif  Autumn    Rabi  \
# 738               Meghalaya       2000     1243.50   875.25  191.90  180.60
# 739               Meghalaya       2001     1089.20   807.35  234.10  148.75
# 740               Meghalaya       2002     1196.35   819.65  129.60  233.20
# 741               Meghalaya       2003     1217.05   902.55  240.90  196.65
# 742               Meghalaya       2004     1497.15  1095.25  329.00  230.75
# 743               Meghalaya       2005     1234.15   871.90  196.75  221.60
# 744               Meghalaya       2006      949.30   652.90  174.95  133.60
# 745               Meghalaya       2007     1376.40  1069.90  329.70  196.55
# 746               Meghalaya       2008     1169.85   908.65  200.45  155.85
# 747               Meghalaya       2009     1034.10   804.70  164.10  106.15
# 748               Meghalaya       2010     1355.75   903.15  217.25  255.85
# ...

# %%
df_rain.shape
# Out:
# (777, 8)

# %%
df_rain = pd.read_csv('rainfall_mm__per_season_per_district_1.csv')

# %%
df_rain.State_Name[df_rain['State_Name']=='Madhya Maharashtra'] = 'Maharashtra'
# Out:
# <ipython-input-137-161d58c8d05c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain.State_Name[df_rain['State_Name']=='Madhya Maharashtra'] = 'Maharashtra'

# %%
df_rain_deep = copy.deepcopy(df_rain[df_rain['State_Name']=='Maharashtra'])
df_rain_deep['State_Name'] = 'Dadra and Nagar Haveli'
df_rain = df_rain.append(df_rain_deep)
df_rain.shape
# Out:
# (798, 8)

# %%
df_rain['Kharif'][df_rain['State_Name']=='Dadra and Nagar Haveli'] = df_rain['Kharif'][df_rain['State_Name']=='Dadra and Nagar Haveli'].apply(lambda x:x/5)
df_rain['Whole Year'][df_rain['State_Name']=='Dadra and Nagar Haveli'] = df_rain['Whole Year'][df_rain['State_Name']=='Dadra and Nagar Haveli'].apply(lambda x:x/5)
df_rain['Rabi'][df_rain['State_Name']=='Dadra and Nagar Haveli'] = df_rain['Rabi'][df_rain['State_Name']=='Dadra and Nagar Haveli'].apply(lambda x:x/5)
df_rain['Winter'][df_rain['State_Name']=='Dadra and Nagar Haveli'] = df_rain['Winter'][df_rain['State_Name']=='Dadra and Nagar Haveli'].apply(lambda x:x/5)
df_rain['Autumn'][df_rain['State_Name']=='Dadra and Nagar Haveli'] = df_rain['Autumn'][df_rain['State_Name']=='Dadra and Nagar Haveli'].apply(lambda x:x/5)
df_rain['Summer'][df_rain['State_Name']=='Dadra and Nagar Haveli'] = df_rain['Summer'][df_rain['State_Name']=='Dadra and Nagar Haveli'].apply(lambda x:x/5)
# Out:
# <ipython-input-148-d3d1ee2ae3de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Kharif'][df_rain['State_Name']=='Dadra and Nagar Haveli'] = df_rain['Kharif'][df_rain['State_Name']=='Dadra and Nagar Haveli'].apply(lambda x:x/5)
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-148-d3d1ee2ae3de>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_rain['Kharif'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Kharif'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
df_rain['Whole Year'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Whole Year'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
df_rain['Rabi'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Rabi'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
df_rain['Winter'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Winter'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
df_rain['Autumn'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Autumn'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
df_rain['Summer'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Summer'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
# Out:
# <ipython-input-161-b86f32c17048>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Kharif'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Kharif'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
# <ipython-input-161-b86f32c17048>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Whole Year'][df_rain['State_Name']=='Naga Mani Mizo Tripura'] = df_rain['Whole Year'][df_rain['State_Name']=='Naga Mani Mizo Tripura'].apply(lambda x:x/4)
# <ipython-input-161-b86f32c17048>:3: SettingWithCopyWarning:
# ...

# %%
df_rain_temp = df_rain[df_rain['State_Name']=='Naga Mani Mizo Tripura']
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_deep['State_Name'] = 'Tripura'
df_rain = df_rain.append(df_rain_deep)
df_rain_deep['State_Name'] = 'Manipur'
df_rain = df_rain.append(df_rain_deep)
df_rain_deep['State_Name'] = 'Mizoram'
df_rain = df_rain.append(df_rain_deep)
df_rain_deep['State_Name'] = 'Nagaland'
df_rain = df_rain.append(df_rain_deep)
df_rain = df_rain[df_rain['State_Name']!='Naga Mani Mizo Tripura']

# %%
df_rain.tail(60)
# Out:
#    State_Name  Crop_Year  Whole Year   Kharif   Autumn     Rabi   Summer  \
# 45    Manipur       2000     590.975  385.775  120.875  104.300  235.800
# 46    Manipur       2001     537.250  399.750  133.850   59.100  218.850
# 47    Manipur       2002     560.575  374.200   81.150   76.725  233.525
# 48    Manipur       2003     540.550  399.625  115.875   74.550  253.850
# 49    Manipur       2004     588.425  443.950  120.925   91.725  250.425
# 50    Manipur       2005     459.175  333.875  121.725   66.050  136.850
# 51    Manipur       2006     468.000  335.925   80.375   36.575  234.725
# 52    Manipur       2007     634.550  464.300  151.775  101.100  235.850
# 53    Manipur       2008     437.225  348.300   93.475   38.725  145.775
# 54    Manipur       2009     434.425  344.525  107.375   37.525  143.625
# 55    Manipur       2010     573.800  425.575  132.500   74.725  216.775
# 56    Manipur       2011     473.025  351.500   87.725   37.825  197.550
# ...

# %%
df_yield.State_Name[df_yield['State_Name']=='Telangana '] = 'Telangana'
# Out:
# <ipython-input-178-dd6067a0be1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yield.State_Name[df_yield['State_Name']=='Telangana '] = 'Telangana'

# %%
df_yield['State_Name'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df_rain['Kharif'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'] = df_rain['Kharif'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'].apply(lambda x:x/2)
df_rain['Whole Year'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'] = df_rain['Whole Year'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'].apply(lambda x:x/2)
df_rain['Rabi'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'] = df_rain['Rabi'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'].apply(lambda x:x/2)
df_rain['Winter'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'] = df_rain['Winter'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'].apply(lambda x:x/2)
df_rain['Autumn'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'] = df_rain['Autumn'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'].apply(lambda x:x/2)
df_rain['Summer'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'] = df_rain['Summer'][df_rain['State_Name']=='Haryana Delhi & Chandigarh'].apply(lambda x:x/2)
# Out:
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df_rain_temp = df_rain[df_rain['State_Name']=='Haryana Delhi & Chandigarh']
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_deep['State_Name'] = 'Haryana'
df_rain = df_rain.append(df_rain_deep)
df_rain_deep['State_Name'] = 'Chandigarh'
df_rain = df_rain.append(df_rain_deep)
df_rain = df_rain[df_rain['State_Name']!='Haryana Delhi & Chandigarh']

# %%
df_rain['Kharif'][df_rain['State_Name']=='Chandigarh'] = df_rain['Kharif'][df_rain['State_Name']=='Chandigarh'].apply(lambda x:x/2)
df_rain['Whole Year'][df_rain['State_Name']=='Chandigarh'] = df_rain['Whole Year'][df_rain['State_Name']=='Chandigarh'].apply(lambda x:x/2)
df_rain['Rabi'][df_rain['State_Name']=='Chandigarh'] = df_rain['Rabi'][df_rain['State_Name']=='Chandigarh'].apply(lambda x:x/2)
df_rain['Winter'][df_rain['State_Name']=='Chandigarh'] = df_rain['Winter'][df_rain['State_Name']=='Chandigarh'].apply(lambda x:x/2)
df_rain['Autumn'][df_rain['State_Name']=='Chandigarh'] = df_rain['Autumn'][df_rain['State_Name']=='Chandigarh'].apply(lambda x:x/2)
df_rain['Summer'][df_rain['State_Name']=='Chandigarh'] = df_rain['Summer'][df_rain['State_Name']=='Chandigarh'].apply(lambda x:x/2)

# %%
df_rain.tail(60)
# Out:
#      State_Name  Crop_Year  Whole Year   Kharif   Autumn     Rabi   Summer  \
# 45     Nagaland       2000     590.975  385.775  120.875  104.300  235.800
# 46     Nagaland       2001     537.250  399.750  133.850   59.100  218.850
# 47     Nagaland       2002     560.575  374.200   81.150   76.725  233.525
# 48     Nagaland       2003     540.550  399.625  115.875   74.550  253.850
# 49     Nagaland       2004     588.425  443.950  120.925   91.725  250.425
# 50     Nagaland       2005     459.175  333.875  121.725   66.050  136.850
# 51     Nagaland       2006     468.000  335.925   80.375   36.575  234.725
# 52     Nagaland       2007     634.550  464.300  151.775  101.100  235.850
# 53     Nagaland       2008     437.225  348.300   93.475   38.725  145.775
# 54     Nagaland       2009     434.425  344.525  107.375   37.525  143.625
# 55     Nagaland       2010     573.800  425.575  132.500   74.725  216.775
# ...

# %%
df_yield.State_Name[df_yield['State_Name']=='Jammu and Kashmir '] = 'Jammu and Kashmir'
# Out:
# <ipython-input-195-6e338df6f414>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yield.State_Name[df_yield['State_Name']=='Jammu and Kashmir '] = 'Jammu and Kashmir'

# %%
df_rain.State_Name[df_rain['State_Name']=='Jammu & Kashmir'] = 'Jammu and Kashmir'
df_rain.State_Name[df_rain['State_Name']=='Coastal Andhra Pradesh'] = 'Andhra Pradesh'
df_rain.State_Name[df_rain['State_Name']=='Konkan & Goa'] = 'Goa'
# Out:
# <ipython-input-196-8662cb447955>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain.State_Name[df_rain['State_Name']=='Coastal Andhra Pradesh'] = 'Andhra Pradesh'
# <ipython-input-196-8662cb447955>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain.State_Name[df_rain['State_Name']=='Konkan & Goa'] = 'Goa'

# %%
df_rain.State_Name[df_rain['State_Name']=='Gujarat Region'] = 'Gujarat'
# Out:
# <ipython-input-198-7da7a8f99db4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain.State_Name[df_rain['State_Name']=='Gujarat Region'] = 'Gujarat'

# %%
df_rain['Kharif'][df_rain['State_Name']=='Goa'] = df_rain['Kharif'][df_rain['State_Name']=='Goa'].apply(lambda x:x/2)
df_rain['Whole Year'][df_rain['State_Name']=='Goa'] = df_rain['Whole Year'][df_rain['State_Name']=='Goa'].apply(lambda x:x/2)
df_rain['Rabi'][df_rain['State_Name']=='Goa'] = df_rain['Rabi'][df_rain['State_Name']=='Goa'].apply(lambda x:x/2)
df_rain['Winter'][df_rain['State_Name']=='Goa'] = df_rain['Winter'][df_rain['State_Name']=='Goa'].apply(lambda x:x/2)
df_rain['Autumn'][df_rain['State_Name']=='Goa'] = df_rain['Autumn'][df_rain['State_Name']=='Goa'].apply(lambda x:x/2)
df_rain['Summer'][df_rain['State_Name']=='Goa'] = df_rain['Summer'][df_rain['State_Name']=='Goa'].apply(lambda x:x/2)
# Out:
# <ipython-input-199-26da7e74dadb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Kharif'][df_rain['State_Name']=='Goa'] = df_rain['Kharif'][df_rain['State_Name']=='Goa'].apply(lambda x:x/2)
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-199-26da7e74dadb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_rain.State_Name[df_rain['State_Name']=='Orissa'] = 'Odisha'
# Out:
# <ipython-input-205-049820df887a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain.State_Name[df_rain['State_Name']=='Orissa'] = 'Odisha'

# %%
df_rain = df_rain[df_rain['State_Name']!='Lakshadweep']
df_rain = df_rain[df_rain['State_Name']!='Saurashtra & Kutch']
df_rain = df_rain[df_rain['State_Name']!='Matathwada']
df_rain = df_rain[df_rain['State_Name']!='Vidarbha']
df_rain = df_rain[df_rain['State_Name']!='Rayalseema']

# %%
df_yield = df_yield[df_yield['State_Name']!='Puducherry']

# %%
df_rain_temp = df_rain[df_rain['State_Name']=='East Uttar Pradesh']
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_temp2 = df_rain[df_rain['State_Name']=='West Uttar Pradesh']
df_rain_deep2 = copy.deepcopy(df_rain_temp2)
print(df_rain_deep.shape)
print(df_rain_deep2.shape)
# Out:
# (21, 8)
# (21, 8)

# %%
df_rain_deep.reset_index(inplace = True)

# %%
df_rain_deep2.reset_index(inplace = True)

# %%
for col in df_rain_deep:
    if col not in ['State_Name', 'Crop_Year']:
        df_rain_deep[col] = df_rain_deep[col] + df_rain_deep2[col]

# %%
df_rain_deep.drop(columns='index', inplace=True)

# %%
df_rain_deep
# Out:
#             State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  \
# 0   East Uttar Pradesh       1997       938.5   824.2    71.7   75.9   220.5
# 1   East Uttar Pradesh       1998      1528.2  1411.3   202.1   86.5   172.9
# 2   East Uttar Pradesh       1999      1739.2  1667.3   577.1   39.9   211.0
# 3   East Uttar Pradesh       2000      1718.2  1580.9   303.1   75.1   416.9
# 4   East Uttar Pradesh       2001      1635.5  1547.8   270.4   31.4   465.9
# 5   East Uttar Pradesh       2002      1314.3  1147.4   472.1  116.3   133.5
# 6   East Uttar Pradesh       2003      2143.9  1984.1   698.7  151.7   220.1
# 7   East Uttar Pradesh       2004      1389.2  1266.1   304.0   75.7   296.5
# 8   East Uttar Pradesh       2005      1496.0  1386.3   349.9   94.5   141.6
# 9   East Uttar Pradesh       2006      1161.4  1052.5   143.0   47.6   247.0
# 10  East Uttar Pradesh       2007      1313.7  1090.7   184.9  183.8   196.3
# ...

# %%
df_rain_deep.State_Name[df_rain_deep['State_Name']=='East Uttar Pradesh'] = 'Uttar Pradesh'
# Out:
# <ipython-input-243-e89aa0d6579f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain_deep.State_Name[df_rain_deep['State_Name']=='East Uttar Pradesh'] = 'Uttar Pradesh'

# %%
df_rain_deep
# Out:
#        State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  \
# 0   Uttar Pradesh       1997       938.5   824.2    71.7   75.9   220.5
# 1   Uttar Pradesh       1998      1528.2  1411.3   202.1   86.5   172.9
# 2   Uttar Pradesh       1999      1739.2  1667.3   577.1   39.9   211.0
# 3   Uttar Pradesh       2000      1718.2  1580.9   303.1   75.1   416.9
# 4   Uttar Pradesh       2001      1635.5  1547.8   270.4   31.4   465.9
# 5   Uttar Pradesh       2002      1314.3  1147.4   472.1  116.3   133.5
# 6   Uttar Pradesh       2003      2143.9  1984.1   698.7  151.7   220.1
# 7   Uttar Pradesh       2004      1389.2  1266.1   304.0   75.7   296.5
# 8   Uttar Pradesh       2005      1496.0  1386.3   349.9   94.5   141.6
# 9   Uttar Pradesh       2006      1161.4  1052.5   143.0   47.6   247.0
# 10  Uttar Pradesh       2007      1313.7  1090.7   184.9  183.8   196.3
# 11  Uttar Pradesh       2008      1753.2  1693.6   219.0   18.4   465.4
# ...

# %%
df_rain = df_rain.append(df_rain_deep)

# %%
df_rain = df_rain[df_rain['State_Name']!='East Uttar Pradesh']
df_rain = df_rain[df_rain['State_Name']!='West Uttar Pradesh']

# %%
df_rain.reset_index(inplace = True)

# %%
df_rain.drop(columns='index', inplace=True)

# %%
df_rain
# Out:
#                       State_Name  Crop_Year  Whole Year  Kharif  Autumn  \
# 0    Andaman and Nicobar Islands       1997      2755.1  2117.5   568.9
# 1    Andaman and Nicobar Islands       1998      2846.4  2179.8   956.4
# 2    Andaman and Nicobar Islands       1999      2699.7  1795.5   762.8
# 3    Andaman and Nicobar Islands       2000      2763.2  1565.4   571.3
# 4    Andaman and Nicobar Islands       2001      3080.9  1783.0   602.0
# ..                           ...        ...         ...     ...     ...
# 751                Uttar Pradesh       2013      1974.2  1786.4   289.0
# 752                Uttar Pradesh       2014      1188.1   945.7   280.7
# 753                Uttar Pradesh       2015      1186.0   926.9    67.1
# 754                Uttar Pradesh       2016      1564.5  1465.9   230.9
# 755                Uttar Pradesh       2017      1280.2  1190.2   229.5
#
#       Rabi  Summer  Winter
# 0    356.5   496.2   340.7
# 1    317.7   948.9   317.7
# ...

# %%
df_rain_temp = df_rain[df_rain['State_Name']=='East Rajasthan']
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_temp2 = df_rain[df_rain['State_Name']=='West Rajasthan']
df_rain_deep2 = copy.deepcopy(df_rain_temp2)
print(df_rain_deep.shape)
print(df_rain_deep2.shape)    
df_rain_deep.reset_index(inplace = True)
df_rain_deep2.reset_index(inplace = True)
# Out:
# (21, 8)
# (21, 8)

# %%
for col in df_rain_deep:
    if col not in ['State_Name', 'Crop_Year']:
        df_rain_deep[col] = df_rain_deep[col] + df_rain_deep2[col]
df_rain_deep.drop(columns='index', inplace=True)
df_rain_deep
# Out:
#         State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  \
# 0   East Rajasthan       1997       919.0   814.7   196.6   69.8   173.3
# 1   East Rajasthan       1998       755.4   721.7   272.7   30.5   109.6
# 2   East Rajasthan       1999       612.7   550.7    94.7   16.5   122.9
# 3   East Rajasthan       2000       675.3   641.6    35.9    8.6    59.1
# 4   East Rajasthan       2001       836.5   765.2    27.0   24.7   211.4
# 5   East Rajasthan       2002       377.7   324.7    62.7   33.0   120.7
# 6   East Rajasthan       2003       994.7   935.9   107.8   53.5   127.7
# 7   East Rajasthan       2004       802.9   773.7    79.5   14.0   108.6
# 8   East Rajasthan       2005       828.7   762.5   248.3   46.6   116.6
# 9   East Rajasthan       2006      1109.7  1052.3   127.9   36.1   135.9
# 10  East Rajasthan       2007       886.5   786.7   131.7   90.3   117.3
# 11  East Rajasthan       2008       968.7   880.2   139.1   41.6   290.7
# ...

# %%
df_rain_deep.State_Name[df_rain_deep['State_Name']=='East Rajasthan'] = 'Rajasthan'
df_rain_deep
# Out:
# <ipython-input-262-f64b0dfb8fa9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain_deep.State_Name[df_rain_deep['State_Name']=='East Rajasthan'] = 'Rajasthan'
#    State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  Winter
# 0   Rajasthan       1997       919.0   814.7   196.6   69.8   173.3    41.8
# 1   Rajasthan       1998       755.4   721.7   272.7   30.5   109.6    13.3
# 2   Rajasthan       1999       612.7   550.7    94.7   16.5   122.9    16.1
# 3   Rajasthan       2000       675.3   641.6    35.9    8.6    59.1     2.5
# 4   Rajasthan       2001       836.5   765.2    27.0   24.7   211.4     8.4
# 5   Rajasthan       2002       377.7   324.7    62.7   33.0   120.7    29.3
# 6   Rajasthan       2003       994.7   935.9   107.8   53.5   127.7    51.6
# ...

# %%
df_rain = df_rain.append(df_rain_deep)
df_rain = df_rain[df_rain['State_Name']!='East Rajasthan']
df_rain = df_rain[df_rain['State_Name']!='West Rajasthan']

# %%
df_rain.reset_index(inplace = True)
df_rain.drop(columns='index', inplace=True)
df_rain
# Out:
#                       State_Name  Crop_Year  Whole Year  Kharif  Autumn  \
# 0    Andaman and Nicobar Islands       1997      2755.1  2117.5   568.9
# 1    Andaman and Nicobar Islands       1998      2846.4  2179.8   956.4
# 2    Andaman and Nicobar Islands       1999      2699.7  1795.5   762.8
# 3    Andaman and Nicobar Islands       2000      2763.2  1565.4   571.3
# 4    Andaman and Nicobar Islands       2001      3080.9  1783.0   602.0
# ..                           ...        ...         ...     ...     ...
# 730                    Rajasthan       2013      1225.5  1155.8   187.4
# 731                    Rajasthan       2014       985.7   884.8   225.5
# 732                    Rajasthan       2015      1109.1   947.0    61.9
# 733                    Rajasthan       2016      1207.6  1180.5   101.9
# 734                    Rajasthan       2017      1008.6   932.8    67.6
#
#       Rabi  Summer  Winter
# 0    356.5   496.2   340.7
# 1    317.7   948.9   317.7
# ...

# %%
df_rain_temp = df_rain[df_rain['State_Name']=='East Madhya Pradesh']
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_temp2 = df_rain[df_rain['State_Name']=='West Madhya Pradesh']
df_rain_deep2 = copy.deepcopy(df_rain_temp2)
print(df_rain_deep.shape)
print(df_rain_deep2.shape)    
df_rain_deep.reset_index(inplace = True)
df_rain_deep2.reset_index(inplace = True)
# Out:
# (21, 8)
# (21, 8)

# %%
for col in df_rain_deep:
    if col not in ['State_Name', 'Crop_Year']:
        df_rain_deep[col] = df_rain_deep[col] + df_rain_deep2[col]
df_rain_deep.drop(columns='index', inplace=True)
df_rain_deep
# Out:
#              State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  \
# 0   East Madhya Pradesh       1997      2415.4  2066.4   392.9  344.0   201.2
# 1   East Madhya Pradesh       1998      1940.3  1818.4   533.2  118.4   187.9
# 2   East Madhya Pradesh       1999      2496.6  2432.4  1018.7   54.9   258.8
# 3   East Madhya Pradesh       2000         NaN  1449.5   146.0    NaN   298.6
# 4   East Madhya Pradesh       2001      1957.1  1889.6   250.1   38.7   516.9
# 5   East Madhya Pradesh       2002      1634.3  1555.6   382.1   69.6   243.4
# 6   East Madhya Pradesh       2003      2384.5  2290.7   769.6   92.9   251.3
# 7   East Madhya Pradesh       2004      1803.4  1748.4   244.5   46.2   302.6
# 8   East Madhya Pradesh       2005      2118.6  1957.5   382.4  117.6   298.2
# 9   East Madhya Pradesh       2006      2112.6  1932.7   298.9  139.0   189.1
# 10  East Madhya Pradesh       2007      1460.3  1342.8   271.5   96.6   199.0
# ...

# %%
df_rain_deep.State_Name[df_rain_deep['State_Name']=='East Madhya Pradesh'] = 'Madhya Pradesh'
df_rain_deep
# Out:
# <ipython-input-267-bc3a11c296fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain_deep.State_Name[df_rain_deep['State_Name']=='East Madhya Pradesh'] = 'Madhya Pradesh'
#         State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  \
# 0   Madhya Pradesh       1997      2415.4  2066.4   392.9  344.0   201.2
# 1   Madhya Pradesh       1998      1940.3  1818.4   533.2  118.4   187.9
# 2   Madhya Pradesh       1999      2496.6  2432.4  1018.7   54.9   258.8
# 3   Madhya Pradesh       2000         NaN  1449.5   146.0    NaN   298.6
# 4   Madhya Pradesh       2001      1957.1  1889.6   250.1   38.7   516.9
# 5   Madhya Pradesh       2002      1634.3  1555.6   382.1   69.6   243.4
# 6   Madhya Pradesh       2003      2384.5  2290.7   769.6   92.9   251.3
# ...

# %%
df_rain = df_rain.append(df_rain_deep)
df_rain = df_rain[df_rain['State_Name']!='East Madhya Pradesh']
df_rain = df_rain[df_rain['State_Name']!='West Madhya Pradesh']

# %%
df_rain.reset_index(inplace = True)
df_rain.drop(columns='index', inplace=True)
df_rain
# Out:
#                       State_Name  Crop_Year  Whole Year  Kharif  Autumn  \
# 0    Andaman and Nicobar Islands       1997      2755.1  2117.5   568.9
# 1    Andaman and Nicobar Islands       1998      2846.4  2179.8   956.4
# 2    Andaman and Nicobar Islands       1999      2699.7  1795.5   762.8
# 3    Andaman and Nicobar Islands       2000      2763.2  1565.4   571.3
# 4    Andaman and Nicobar Islands       2001      3080.9  1783.0   602.0
# ..                           ...        ...         ...     ...     ...
# 709               Madhya Pradesh       2013      2918.2  2800.1   369.8
# 710               Madhya Pradesh       2014      1789.8  1581.6   395.6
# 711               Madhya Pradesh       2015      1981.5  1708.8   176.4
# 712               Madhya Pradesh       2016      2438.0  2362.3   310.0
# 713               Madhya Pradesh       2017      1609.1  1566.1   327.7
#
#       Rabi  Summer  Winter
# 0    356.5   496.2   340.7
# 1    317.7   948.9   317.7
# ...

# %%
df_rain_temp = df_rain[df_rain['State_Name']=='North Interior Karnataka']
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_temp2 = df_rain[df_rain['State_Name']=='South Interior Karnataka']
df_rain_deep2 = copy.deepcopy(df_rain_temp2)
df_rain_temp3 = df_rain[df_rain['State_Name']=='Coastal Karnataka']
df_rain_deep3 = copy.deepcopy(df_rain_temp3)
print(df_rain_deep.shape)
print(df_rain_deep2.shape)    
print(df_rain_deep3.shape)    
df_rain_deep.reset_index(inplace = True)
df_rain_deep2.reset_index(inplace = True)
df_rain_deep3.reset_index(inplace = True)
# Out:
# (21, 8)
# (21, 8)
# (21, 8)

# %%
for col in df_rain_deep:
    if col not in ['State_Name', 'Crop_Year']:
        df_rain_deep[col] = df_rain_deep[col] + df_rain_deep2[col] + df_rain_deep3[col]
df_rain_deep.drop(columns='index', inplace=True)
df_rain_deep
# Out:
#                   State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  \
# 0   North Interior Karnataka       1997      6229.2  5582.6   670.6  560.8
# 1   North Interior Karnataka       1998      5673.7  5299.7  1564.3  222.2
# 2   North Interior Karnataka       1999      5590.3  4924.5  1155.0  110.1
# 3   North Interior Karnataka       2000      5270.9  4785.0  1093.1  161.5
# 4   North Interior Karnataka       2001      4635.9  4149.2   958.7  286.2
# 5   North Interior Karnataka       2002      4079.4  3647.6   945.4  150.0
# 6   North Interior Karnataka       2003      4308.2  4100.5   820.4  184.3
# 7   North Interior Karnataka       2004      4845.3  3982.7   674.3  259.3
# 8   North Interior Karnataka       2005      5597.7  5121.9  1284.2  321.7
# 9   North Interior Karnataka       2006      5518.4  4643.2   970.2  313.3
# 10  North Interior Karnataka       2007      5928.1  5522.5  1380.2  228.9
# ...

# %%
df_rain_deep.State_Name[df_rain_deep['State_Name']=='North Interior Karnataka'] = 'Karnataka'
df_rain_deep
# Out:
# <ipython-input-277-5e76760b2d5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain_deep.State_Name[df_rain_deep['State_Name']=='North Interior Karnataka'] = 'Karnataka'
#    State_Name  Crop_Year  Whole Year  Kharif  Autumn   Rabi  Summer  Winter
# 0   Karnataka       1997      6229.2  5582.6   670.6  560.8  1366.5   434.8
# 1   Karnataka       1998      5673.7  5299.7  1564.3  222.2  1425.8   172.6
# 2   Karnataka       1999      5590.3  4924.5  1155.0  110.1  1685.7    54.4
# 3   Karnataka       2000      5270.9  4785.0  1093.1  161.5  1647.0    79.7
# 4   Karnataka       2001      4635.9  4149.2   958.7  286.2  1502.8    99.9
# 5   Karnataka       2002      4079.4  3647.6   945.4  150.0  1352.6    80.7
# 6   Karnataka       2003      4308.2  4100.5   820.4  184.3  1280.8    42.0
# ...

# %%
df_rain = df_rain.append(df_rain_deep)
df_rain = df_rain[df_rain['State_Name']!='Coastal Karnataka']
df_rain = df_rain[df_rain['State_Name']!='North Interior Karnataka']
df_rain = df_rain[df_rain['State_Name']!='South Interior Karnataka']

# %%
df_rain.reset_index(inplace = True)
df_rain.drop(columns='index', inplace=True)
df_rain
# Out:
#                       State_Name  Crop_Year  Whole Year  Kharif  Autumn  \
# 0    Andaman and Nicobar Islands       1997      2755.1  2117.5   568.9
# 1    Andaman and Nicobar Islands       1998      2846.4  2179.8   956.4
# 2    Andaman and Nicobar Islands       1999      2699.7  1795.5   762.8
# 3    Andaman and Nicobar Islands       2000      2763.2  1565.4   571.3
# 4    Andaman and Nicobar Islands       2001      3080.9  1783.0   602.0
# ..                           ...        ...         ...     ...     ...
# 667                    Karnataka       2013      6063.3  5559.5  1241.7
# 668                    Karnataka       2014      5625.4  4899.5  1090.7
# 669                    Karnataka       2015      4770.4  3866.6   951.4
# 670                    Karnataka       2016      3932.0  3593.2   571.7
# 671                    Karnataka       2017      4748.9  4290.8  1285.3
#
#       Rabi  Summer  Winter
# 0    356.5   496.2   340.7
# 1    317.7   948.9   317.7
# ...

# %%
df_rain.State_Name[df_rain['State_Name']=='Sub Himalayan West Bengal & Sikkim'] = 'Sikkim'
# Out:
# <ipython-input-285-429d20085ad8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain.State_Name[df_rain['State_Name']=='Sub Himalayan West Bengal & Sikkim'] = 'Sikkim'

# %%
df_rain['Kharif'][df_rain['State_Name']=='Sikkim'] = df_rain['Kharif'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
df_rain['Whole Year'][df_rain['State_Name']=='Sikkim'] = df_rain['Whole Year'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
df_rain['Rabi'][df_rain['State_Name']=='Sikkim'] = df_rain['Rabi'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
df_rain['Winter'][df_rain['State_Name']=='Sikkim'] = df_rain['Winter'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
df_rain['Autumn'][df_rain['State_Name']=='Sikkim'] = df_rain['Autumn'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
df_rain['Summer'][df_rain['State_Name']=='Sikkim'] = df_rain['Summer'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
# Out:
# <ipython-input-286-479fb515ac31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Kharif'][df_rain['State_Name']=='Sikkim'] = df_rain['Kharif'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
# <ipython-input-286-479fb515ac31>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Whole Year'][df_rain['State_Name']=='Sikkim'] = df_rain['Whole Year'][df_rain['State_Name']=='Sikkim'].apply(lambda x:x/2)
# <ipython-input-286-479fb515ac31>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_rain_temp = df_rain[df_rain['State_Name']=='Gangetic West Bengal']
df_rain_deep = copy.deepcopy(df_rain_temp)
df_rain_temp2 = df_rain[df_rain['State_Name']=='Sikkim']
df_rain_deep2 = copy.deepcopy(df_rain_temp2)
print(df_rain_deep.shape)
print(df_rain_deep2.shape)    
df_rain_deep.reset_index(inplace = True)
df_rain_deep2.reset_index(inplace = True)
# Out:
# (21, 8)
# (21, 8)

# %%
for col in df_rain_deep:
    if col not in ['State_Name', 'Crop_Year']:
        df_rain_deep[col] = df_rain_deep[col] + df_rain_deep2[col]
df_rain_deep.drop(columns='index', inplace=True)
df_rain_deep
# Out:
#               State_Name  Crop_Year  Whole Year   Kharif  Autumn    Rabi  \
# 0   Gangetic West Bengal       1997     2933.40  2348.80  514.40  403.15
# 1   Gangetic West Bengal       1998     3460.25  2730.90  831.70  515.30
# 2   Gangetic West Bengal       1999     3618.65  3104.45  988.15  128.60
# 3   Gangetic West Bengal       2000     3026.10  2365.45  778.95  282.35
# 4   Gangetic West Bengal       2001     2846.90  2278.40  728.35  219.20
# 5   Gangetic West Bengal       2002     2886.80  2302.95  605.80  378.95
# 6   Gangetic West Bengal       2003     2858.35  2328.70  768.70  341.75
# 7   Gangetic West Bengal       2004     2926.75  2502.35  781.55  207.80
# 8   Gangetic West Bengal       2005     3008.75  2462.45  823.50  336.80
# 9   Gangetic West Bengal       2006     2791.55  2351.80  718.20  183.60
# 10  Gangetic West Bengal       2007     3260.85  2741.05  784.75  313.55
# 11  Gangetic West Bengal       2008     2900.15  2452.25  536.90  267.95
# ...

# %%
df_rain_deep.State_Name[df_rain_deep['State_Name']=='Gangetic West Bengal'] = 'West Bengal'
df_rain_deep
# Out:
# <ipython-input-290-322b430f2b39>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain_deep.State_Name[df_rain_deep['State_Name']=='Gangetic West Bengal'] = 'West Bengal'
#      State_Name  Crop_Year  Whole Year   Kharif  Autumn    Rabi   Summer  \
# 0   West Bengal       1997     2933.40  2348.80  514.40  403.15   869.45
# 1   West Bengal       1998     3460.25  2730.90  831.70  515.30   825.05
# 2   West Bengal       1999     3618.65  3104.45  988.15  128.60  1018.15
# 3   West Bengal       2000     3026.10  2365.45  778.95  282.35  1055.20
# 4   West Bengal       2001     2846.90  2278.40  728.35  219.20  1086.50
# 5   West Bengal       2002     2886.80  2302.95  605.80  378.95   952.20
# 6   West Bengal       2003     2858.35  2328.70  768.70  341.75   848.55
# ...

# %%
df_rain = df_rain.append(df_rain_deep)
df_rain = df_rain[df_rain['State_Name']!='Gangetic West Bengal']

# %%
df_rain.reset_index(inplace = True)
df_rain.drop(columns='index', inplace=True)
df_rain
# Out:
#                       State_Name  Crop_Year  Whole Year   Kharif  Autumn  \
# 0    Andaman and Nicobar Islands       1997     2755.10  2117.50  568.90
# 1    Andaman and Nicobar Islands       1998     2846.40  2179.80  956.40
# 2    Andaman and Nicobar Islands       1999     2699.70  1795.50  762.80
# 3    Andaman and Nicobar Islands       2000     2763.20  1565.40  571.30
# 4    Andaman and Nicobar Islands       2001     3080.90  1783.00  602.00
# ..                           ...        ...         ...      ...     ...
# 667                  West Bengal       2013     2967.15  2463.90  861.10
# 668                  West Bengal       2014     2422.70  2018.20  487.75
# 669                  West Bengal       2015     2789.60  2305.90  400.95
# 670                  West Bengal       2016     2739.40  2308.95  628.45
# 671                  West Bengal       2017     2911.05  2470.95  694.90
#
#        Rabi   Summer  Winter
# 0    356.50   496.20  340.70
# 1    317.70   948.90  317.70
# ...

# %%
#array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',      'Summer     ', 'Winter     '], dtype=object)

# %%
df_yield.Season[df_yield['Season']=='Kharif     '] = 'Kharif'
df_yield.Season[df_yield['Season']=='Whole Year '] = 'Whole Year'
df_yield.Season[df_yield['Season']=='Autumn     '] = 'Autumn'
df_yield.Season[df_yield['Season']=='Rabi       '] = 'Rabi'
df_yield.Season[df_yield['Season']=='Summer     '] = 'Summer'
df_yield.Season[df_yield['Season']=='Winter     '] = 'Winter'
# Out:
# <ipython-input-327-644ada2d0069>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yield.Season[df_yield['Season']=='Kharif     '] = 'Kharif'
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\series.py:1020: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-327-644ada2d0069>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_yield['Season'].unique()
# Out:
# array(['Kharif', 'Whole Year', 'Autumn', 'Rabi', 'Summer', 'Winter'],
#       dtype=object)

# %%
df_rain_deep_copy = copy.deepcopy(df_rain)

# %%
df_yield_deep_copy = copy.deepcopy(df_yield)

# %%
df_rain
# Out:
#                       State_Name  Crop_Year  Whole Year   Kharif  Autumn  \
# 0    Andaman and Nicobar Islands       1997     2755.10  2117.50  568.90
# 1    Andaman and Nicobar Islands       1998     2846.40  2179.80  956.40
# 2    Andaman and Nicobar Islands       1999     2699.70  1795.50  762.80
# 3    Andaman and Nicobar Islands       2000     2763.20  1565.40  571.30
# 4    Andaman and Nicobar Islands       2001     3080.90  1783.00  602.00
# ..                           ...        ...         ...      ...     ...
# 667                  West Bengal       2013     2967.15  2463.90  861.10
# 668                  West Bengal       2014     2422.70  2018.20  487.75
# 669                  West Bengal       2015     2789.60  2305.90  400.95
# 670                  West Bengal       2016     2739.40  2308.95  628.45
# 671                  West Bengal       2017     2911.05  2470.95  694.90
#
#        Rabi   Summer  Winter
# 0    356.50   496.20  340.70
# 1    317.70   948.90  317.70
# ...

# %%
df_yield
# Out:
#                          State_Name  Crop_Year      Season  \
# 0       Andaman and Nicobar Islands       2000      Kharif
# 1       Andaman and Nicobar Islands       2000      Kharif
# 2       Andaman and Nicobar Islands       2000      Kharif
# 3       Andaman and Nicobar Islands       2000  Whole Year
# 4       Andaman and Nicobar Islands       2000  Whole Year
# ...                             ...        ...         ...
# 246086                  West Bengal       2014      Summer
# 246087                  West Bengal       2014      Summer
# 246088                  West Bengal       2014  Whole Year
# 246089                  West Bengal       2014      Winter
# 246090                  West Bengal       2014      Winter
#
#                        Crop  tonnes/hectare_yield
# 0                  Arecanut              1.594896
# 1       Other Kharif pulses              0.500000
# 2                      Rice              3.147059
# 3                    Banana              3.642045
# ...

# %%
temp_yield = copy.deepcopy(df_yield.head(40))

# %%
temp_yield.insert(6, 'rainfall_mmdf', 0)

# %%
temp_yield
# Out:
#     rainfall_mm                   State_Name  Crop_Year      Season  \
# 0        1565.4  Andaman and Nicobar Islands       2000      Kharif
# 1        1565.4  Andaman and Nicobar Islands       2000      Kharif
# 2        1565.4  Andaman and Nicobar Islands       2000      Kharif
# 3        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 4        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 5        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 6        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 7        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 8        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 9        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 10       1783.0  Andaman and Nicobar Islands       2001      Kharif
# 11       1783.0  Andaman and Nicobar Islands       2001      Kharif
# 12       1783.0  Andaman and Nicobar Islands       2001      Kharif
# ...

# %%
for row in range(temp_yield.shape[0]):
    temp_rain = df_rain[temp_yield.iloc[row]['State_Name']==df_rain['State_Name']]
    temp_rain1 = temp_rain[temp_rain['Crop_Year']==temp_yield.iloc[row]['Crop_Year']]
    temp_yield['rainfall_mm'].iloc[row] = temp_rain1[temp_yield.iloc[row]['Season']].tolist()[0]
# Out:
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
temp_yield
# Out:
#     rainfall_mm                   State_Name  Crop_Year      Season  \
# 0        1565.4  Andaman and Nicobar Islands       2000      Kharif
# 1        1565.4  Andaman and Nicobar Islands       2000      Kharif
# 2        1565.4  Andaman and Nicobar Islands       2000      Kharif
# 3        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 4        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 5        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 6        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 7        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 8        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 9        2763.2  Andaman and Nicobar Islands       2000  Whole Year
# 10       1783.0  Andaman and Nicobar Islands       2001      Kharif
# 11       1783.0  Andaman and Nicobar Islands       2001      Kharif
# 12       1783.0  Andaman and Nicobar Islands       2001      Kharif
# ...

# %%
# df_yield.insert(5, 'rainfall_mm', 0)
for row in range(0, df_yield.shape[0]):
    temp_rain = df_rain[df_rain['State_Name']==df_yield.iloc[row]['State_Name']]
    temp_rain1 = temp_rain[temp_rain['Crop_Year']==df_yield.iloc[row]['Crop_Year']]
    df_yield['rainfall_mm'].iloc[row] = temp_rain1[df_yield.iloc[row]['Season']].tolist()[0]
# Out:
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-414-48bebaa5e1b5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yield['rainfall_mm'].iloc[row] = temp_rain1[df_yield.iloc[row]['Season']].tolist()[0]
# C:\Users\kulpr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_yield
# Out:
#                          State_Name  Crop_Year      Season  \
# 0       Andaman and Nicobar Islands       2000      Kharif
# 1       Andaman and Nicobar Islands       2000      Kharif
# 2       Andaman and Nicobar Islands       2000      Kharif
# 3       Andaman and Nicobar Islands       2000  Whole Year
# 4       Andaman and Nicobar Islands       2000  Whole Year
# ...                             ...        ...         ...
# 246086                  West Bengal       2014      Summer
# 246087                  West Bengal       2014      Summer
# 246088                  West Bengal       2014  Whole Year
# 246089                  West Bengal       2014      Winter
# 246090                  West Bengal       2014      Winter
#
#                        Crop  tonnes/hectare_yield  rainfall_mm
# 0                  Arecanut              1.594896      1565.40
# 1       Other Kharif pulses              0.500000      1565.40
# 2                      Rice              3.147059      1565.40
# ...

# %%
df_yield.to_csv('yield_rainfall_merged.csv', index = False)
